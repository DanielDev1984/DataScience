# %% [markdown]
# # Aufgaben aus Statistikskript

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 2.3.1

# %% [markdown]
# ## 2.3.2

# %%
# values in NM / mm^2
messwerteZugfestigkeit = np.array([404, 413, 390, 418, 387, 418, 399, 392, 399, 417, 390, 384, 383, 387, 389, 391,
411, 422, 371, 369, 411, 405, 408, 349, 402, 378, 393, 424, 403, 414, 367, 407,
383, 401, 388, 386, 427, 411, 400, 412, 426, 392, 402, 392, 373, 390, 396, 408,
386, 396,])

print(f"Zugfestigkeit [NM / mm^2] (min): {min(messwerteZugfestigkeit)}")
print(f"Zugfestigkeit [NM / mm^2] (min): {max(messwerteZugfestigkeit)}")
print(f"Range [NM / mm^2]: {range(min(messwerteZugfestigkeit), max(messwerteZugfestigkeit))}")
# Out:
# Zugfestigkeit [NM / mm^2] (min): 349
# Zugfestigkeit [NM / mm^2] (min): 427
# Range [NM / mm^2]: range(349, 427)

# %%
# Creating histogram
binwidth = 5
fig, ax = plt.subplots(figsize =(10, 7))
#todo: not sure whether bin-calculation really is correct
ax.hist(messwerteZugfestigkeit,bins=range(min(messwerteZugfestigkeit), max(messwerteZugfestigkeit) + binwidth, binwidth))
 
# Show plot
plt.show()

# %% [markdown]
# ## 2.6.1

# %%
# box-whiskers-plot
fig, ax = plt.subplots()
ax.set_title('Zugfestigkeitswerte [N / mm^2]')
ax.boxplot(messwerteZugfestigkeit, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c8c1050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c8c2950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10a33f950>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c8c4090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c8c4b10>],
#  'means': []}
